# %%
# !pip install pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
a = [[1,2],[5,8]]

# %%
np.array(a)
# Out:
# array([[1, 2],
#        [5, 8]])

# %%
pd.DataFrame(a)
# Out:
#    0  1
# 0  1  2
# 1  5  8

# %%
df = pd.DataFrame([{"maths":1,"science":2},{"maths":3,"science":0}])
df
# Out:
#    maths  science
# 0      1        2
# 1      3        0

# %%
df["maths"]
# Out:
# 0    1
# 1    3
# Name: maths, dtype: int64

# %%
type(df["maths"])
# Out:
# pandas.core.series.Series

# %%
df.info
# Out:
# <bound method DataFrame.info of    maths  science
# 0      1        2
# 1      3        0>

# %%
df.head()
# Out:
#    maths  science
# 0      1        2
# 1      3        0
